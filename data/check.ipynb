# %%
import numpy as np
import pandas as pd

# Load the standardized dataset
file_path = '/Users/hanshookoomsing/Documents/undergraduate_project/LSTM_TensorFlow/data/standardized.csv'
data = pd.read_csv(file_path)

# Ensure the 'Date' column is in date format
data['Date'] = pd.to_datetime(data['Date'])

# Load the previously saved sequences and labels
X = np.load('/Users/hanshookoomsing/Documents/undergraduate_project/LSTM_TensorFlow/data/X_sequences.npy')
y = np.load('/Users/hanshookoomsing/Documents/undergraduate_project/LSTM_TensorFlow/data/y_labels.npy')

# Print shapes to verify
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)

# Load a sample sequence to check its composition
sample_sequence = X[0]
print("Sample sequence shape:", sample_sequence.shape)

# Define the columns expected in the features (excluding 'Date' and 'Stock')
expected_columns = data.columns.drop(['Date', 'Stock']).tolist()

# Check if the columns in the sample sequence match the expected columns
sample_df = pd.DataFrame(sample_sequence, columns=expected_columns)
print("Sample sequence DataFrame:\n", sample_df.head(28))

# Check for the presence of macroeconomic data in the features
macroeconomic_columns = ['GDP', 'Inflation Rate', 'Interest Rate']  # Example macroeconomic columns
for col in macroeconomic_columns:
    if col in sample_df.columns:
        print(f"Column '{col}' is included in the sequence.")
    else:
        print(f"Column '{col}' is NOT included in the sequence.")
# Out:
# Shape of X: (46040, 28, 4)
# Shape of y: (46040,)
# Sample sequence shape: (28, 4)
# Sample sequence DataFrame:
#         Close  Interest Rate  Inflation Rate       GDP
# 0  -0.845468       2.186667        0.709601 -0.915359
# 1  -0.845823       2.146667        0.709601 -0.915135
# 2  -0.845726       2.213333        0.709601 -0.914463
# 3  -0.845403       2.200000        0.709601 -0.914239
# 4  -0.845726       2.248889        0.709601 -0.914015
# 5  -0.844983       2.244444        0.709601 -0.913791
# 6  -0.845403       2.213333        0.709601 -0.913567
# 7  -0.845435       2.311111        0.709601 -0.912671
# 8  -0.845597       2.195556        0.709601 -0.912447
# 9  -0.844628       2.191111        0.709601 -0.912223
# 10 -0.844208       2.186667        0.709601 -0.911999
# 11 -0.844338       2.222222        0.709601 -0.911327
# 12 -0.843692       2.208889        0.709601 -0.911103
# 13 -0.843692       2.244444        0.709601 -0.910879
# ...

# %%
import numpy as np
import pandas as pd

# Load the standardized dataset
file_path = '/Users/hanshookoomsing/Documents/undergraduate_project/LSTM_TensorFlow/data/standardized.csv'
data = pd.read_csv(file_path)

# Ensure the 'Date' column is in date format
data['Date'] = pd.to_datetime(data['Date'])

# Load the previously saved sequences and labels
X = np.load('/Users/hanshookoomsing/Documents/undergraduate_project/LSTM_TensorFlow/data/X_sequences.npy')
y = np.load('/Users/hanshookoomsing/Documents/undergraduate_project/LSTM_TensorFlow/data/y_labels.npy')

# Print shapes to verify
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)

# Load a sample sequence to check its composition
sample_sequence = X[0]
print("Sample sequence shape:", sample_sequence.shape)

# Define the columns expected in the features (excluding 'Date' and 'Stock')
expected_columns = data.columns.drop(['Date', 'Stock']).tolist()

# Check if the columns in the sample sequence match the expected columns
sample_df = pd.DataFrame(sample_sequence, columns=expected_columns)
print("Sample sequence DataFrame:\n", sample_df.head(28))

# Check for the presence of macroeconomic data in the features
macroeconomic_columns = ['GDP', 'Inflation Rate', 'Interest Rate']  # Adjusted macroeconomic columns
for col in macroeconomic_columns:
    if col in sample_df.columns:
        print(f"Column '{col}' is included in the sequence.")
    else:
        print(f"Column '{col}' is NOT included in the sequence.")
# Out:
# Shape of X: (46040, 28, 4)
# Shape of y: (46040,)
# Sample sequence shape: (28, 4)
# Sample sequence DataFrame:
#         Close  Interest Rate  Inflation Rate       GDP
# 0  -0.845468       2.186667        0.709601 -0.915359
# 1  -0.845823       2.146667        0.709601 -0.915135
# 2  -0.845726       2.213333        0.709601 -0.914463
# 3  -0.845403       2.200000        0.709601 -0.914239
# 4  -0.845726       2.248889        0.709601 -0.914015
# 5  -0.844983       2.244444        0.709601 -0.913791
# 6  -0.845403       2.213333        0.709601 -0.913567
# 7  -0.845435       2.311111        0.709601 -0.912671
# 8  -0.845597       2.195556        0.709601 -0.912447
# 9  -0.844628       2.191111        0.709601 -0.912223
# 10 -0.844208       2.186667        0.709601 -0.911999
# 11 -0.844338       2.222222        0.709601 -0.911327
# 12 -0.843692       2.208889        0.709601 -0.911103
# 13 -0.843692       2.244444        0.709601 -0.910879
# ...
